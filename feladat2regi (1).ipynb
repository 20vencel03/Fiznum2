# %% [markdown]
# # 2. FELADAT
#
# Ezt a feladatsort pythonban kell megoldani jupyter notebookban. A programok legyenek modulárisak, használjanak függvényeket! Az ábrák legyenek áttekinthetőek, és szerepeljen rajtuk tengelyfelirat!

# %% [markdown]
# $$ \def\dd{{\textrm{d}}} $$
# # Oszcillátorok numerikus vizsgálata
#
# ## Először ismételjük át az alapokat:
#
# Oszcillátoroknak olyan dinamikai rendszereket nevezünk, melyek mozgása az idő periódikus vagy kvázi-periódikus függvényeként írható le. Az egydimenziós oszcillátor mozgásegyenlete
#
# $$ m \frac{\dd^2x}{\dd t^2} = - \frac{\dd V(x)}{\dd x} $$
#
# alakban írható. Egy szabad oszcillátor teljes energiája mindaddig megmarad, amíg a rendszerben nem hat súrlódási erő (csillapított oszcillátor), illetve nem hatunk rá külső erővel (gerjesztett oszcillátor). Az oszcillátor teljes energiája a kinetikus és a potenciális energia összege, azaz
#
# $$ E_{\textrm{tot}} = \frac{m v^2}{2} + V(x)$$
#
# ### Harmonikus oszcillátor
#
# Amennyiben a $V(x)$ potenciál négyzetes, abban az esetben harmonikus oszcillátorról beszélünk:
#
# $$\begin{eqnarray}
#     V(x) & = & \frac{1}{2}kx^2 \\
#     m \frac{\dd^2x}{\dd t^2} & = & - k x.
# \end{eqnarray}$$
#
# A harmonikus oszcillátor mozgásegyenlete analitikusan is megoldható. A megoldás
#
# $$ x(t) = A \cos( \omega t + \varphi ) $$
#
# alakú, ahol $A$ az amplitúdó - vagyis a legnagyobb kitérés -, $\omega$ a körfrekvencia és $\varphi$ a kezdőfázis $t = 0$-ban. A harmonikus oszcillátor körfrekvenciáját a potenciálban szereplő $k$ állandó és az $m$ tömeg jellegű mennyiség határozza meg:
#
# $$ \omega = \sqrt{\frac{k}{m}} = \frac{2\pi}{T}, $$
#
# ahol $T$ a pediódusidő, melyből $f = 1/T$ módon kaphatjuk meg a frekvenciát.
#
# ## Anharmonikus oszcillátor
#
# Az anharmonikus abban különböznek a harmonikus oszcillátortól, hogy a mozgásukat meghatározó potenciál nem négyzetes alakú. Néhány lehetséges anharmonikus potenciál:
#
# * Negyedrendű potenciál
#
# $$ V(x) = \frac{1}{4}k_4 x^4 $$
#
# * Lennard-Jones potenciál, ld. [a wikipédián](https://en.wikipedia.org/wiki/Lennard-Jones_potential)
#
# $$ V(x) = V_0 \left[ \left( \frac{x_0}{x} \right)^{12} - 2 \left( \frac{x_0}{x} \right)^{6} \right] $$
#
# ## Csillapított és gerjesztett oszcillátor
#
# A csillapított és/vagy gerjesztett oszcillátorok mozgásegyenletében megjelenik egy sebességtől függő és egy további, többnyire időfüggő külső erőtag is:
#
# $$ m \frac{\dd^2x}{\dd t^2} = - \frac{\dd V(x)}{\dd x} - c \frac{\dd x}{\dd t} + F(t) $$
#
# Csillapított és szinuszosan gerjesztett harmonikus oszcillátorok viselkedése analitikusan is egyszerűen vizsgálható. Az alábbi feladatokban ezért ezektől eltérő rendszereket vizsgálunk numerikus módszerek segítségével.

# %% [markdown]
# # Feladatok

# %% [markdown]
# ## Alap 1.a) feladatrész
#
# Számítsuk ki a fent felírt két anharmonikus potenciálhoz tartozó erőt analitikusan (azaz képlet formájában), és a végeredmény képletet írjuk ide markdown/latex formátumban!
# Nem szükséges ehhez programot (pl. sympy) használni.

# %% [markdown]
# [ megoldás helye ]
# * Negyedrendű potenciál esetében
#
# Az erő a potenciál $x$ szerinti deriváltjának a minusz egyszerese.
#
# $$\frac{d(V(x))}{d(x)}= -k_4x^3$$
#
#
# * Lennard-Jones potenciál esetében
#
# $$\frac{d(V(x))}{d(x)}= -12 V_0 \cdot \frac{x_0^{12}}{x^{13}}+12V_0 \cdot \frac{x_0^6}{x^7}$$

# %% [markdown]
# ## Alap 1.b) feladatrész
#
# Írjunk olyan függvényeket, melyek kiszámítják külön-külön a fenti három potenciál (harmonikus, negyedrendű és Lennard-Jones) és az ezekhez tartozó erők értékét a hely függvényében!
# A függvények konstansai legyenek a függvényeken kívül definiált változók! (Azokat belül is tudjuk olvasni.)
# Ezeknek adjunk egységnyi nagyságrendű értékeket!
#
# Úgy írjuk meg e függvényeket, hogy a későbbi feladatrészekben az integrálásnál az erőket, és az energia kiszámolásához a potenciált ezekkel tudjuk kiszámolni, ne kelljen ezek képletét újra beírni! Tehát pl. ne legyen közös függvényben az erő és potenciál kiszámolása! (Ha a 2. részhez újra kellene írni, az hibalehetőség lenne. Ha pedig később módosítani akarjuk, akkor két helyen kellene átírni.)
#
# Ábrázoljuk egy ábrán a potenciálokat és egy másikon az erőket! Az egyensúlyi helyzet a potenciálok és erők ábrájáról is leolvasható. Ellenőrizzük, hogy mindhárom potenciál ábrája ilyen értelemben összhangban van a megfelelő erő ábrájával! Ezen felül az erők ábráján is látszania kell, hogy az egyensúlyi helyzettől való kitérés esetén az erők visszatérítő irányúak.
#
# Próbáljuk úgy módosítani a potenciálok és erők ábráit, hogy az egyensúlyi helyzet a Lennard-Jones potenciál esetén egybe essen a többiével, azaz az x koordináta helyett a potenciálminimumtól való előjeles távolság legyen az x tengelyen! Ehhez először számoljuk ki a Lennard-Jones potenciál minimum helyét! Még érdekesebb összehasonlítást kapunk, ha úgy állítjuk be $k$ értékét, hogy a harmonikus oszcillátor és a Lennard-Jones potenciál minimumában a görbület azonos legyen. Ehhez is végezzünk egy egyszerű számolást!

# %%
# a megoldás helye

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sympy import * # a sympy csomag rutinjainak betöltése
#init_printing()     # szép kimenet

# %%
k = 1
k4 = 1
V0 = 1
x0=1

# %%
def harmonikuspotencial(x):
    potencial = 1/2*k*x**2
    return potencial

# %%
def harmonikuspotencialero(x):
    ero = -k*x
    return ero

# %%
harmonikuspotencialero(5)
# Out:
# -5

# %%
def negyedrendupotencial(x):
    negyedrendupotencial = 1/4*k4*x**4
    
    return negyedrendupotencial

# %%
def negyedrenduero(x):
    negyedrenduero = -k4*x**3
    return negyedrenduero

# %%
def lennardjonespotencial(x):
    
    lennardjones  = V0*((x0**12)/(x**12)-2*((x0**6/x**6)))
    
    return lennardjones

# %%
lennardjonespotencial(2)
# Out:
# -0.031005859375

# %%
def lennardjonesero(x):
    
    ero = -(12*V0*x0**12)/(x**13) + 12*V0*x0**6/(x**7)
    
    return ero

# %%
lennardjonesero(1)
# Out:
# 0.0

# %%
 x = np.linspace(-100, 100, 100)

# %%
harmonikusptval = []

negyedrenduptval = []

lennardjonesptval = []

for i in x:
    
    harmonikusptval.append(harmonikuspotencial(i))
    
    negyedrenduptval.append(negyedrendupotencial(i))
    
    lennardjonesptval.append(lennardjonespotencial(i))

# %%
plt.plot(x, harmonikusptval)

# %%
plt.plot(x, negyedrenduptval)

# %%
plt.plot(x, lennardjonesptval)

# %%
#Az összes erőt egy ábrán ábrázolva a következőket fogom kapni:

plt.plot(x, harmonikusptval, 'r-')
plt.plot(x, negyedrenduptval, 'b-')
plt.plot(x, lennardjonesptval, 'y-')

# %%
 x = np.linspace(-5, 5, 1000)
    
lennardjonesptval2 = []
    
for i in x:
    lennardjonesptval2.append(lennardjonespotencial(i))
        

    
    #lennardjonesptval2.append(lennardjonespotencial(i))

# %%
V0=1

plt.plot(x, lennardjonesptval2)

# %%
import numpy as np
import matplotlib.pyplot as plt

def lj_potential(r, epsilon, sigma):
    return 4 * epsilon * ((sigma / r) ** 12 - (sigma / r) ** 6)

r = np.linspace(0.1, 5, 1000)
epsilon = 1
sigma = 1

potential = lj_potential(r, epsilon, sigma)

plt.plot(r, potential)
plt.xlabel('Distance r')
plt.ylabel('Potential energy')
plt.title('Lennard-Jones Potential')
plt.show()

# %%
harmonikusfval = []

negyedrendufval = []

lennardjonesfval = []

for i in x:
    
    harmonikusfval.append(harmonikuspotencialero(i))
    
    negyedrendufval.append(negyedrenduero(i))
    
    lennardjonesfval.append(lennardjonesero(i))

# %%
plt.plot(x, harmonikusfval)
plt.plot(x, negyedrendufval)

# %%
plt.plot(x, lennardjonesfval)

# %% [markdown]
# A Lennard-Jones potenciálnak ott van minimuma, ahol a deriváltja, vagyis a ható erő zérus.

# %%
# %matplotlib inline
# Ez a két parancs pedig a szimbolikus számításra
from sympy import * # a sympy csomag rutinjainak betöltése
init_printing()     # szép kimenet

# %%
x=symbols('x')
solve(-(12*V0*x0**12)/(x**13) + 12*V0*x0**6/(x**7), x)
# Out:
# ⎡         1   √3⋅ⅈ    1   √3⋅ⅈ  1   √3⋅ⅈ  1   √3⋅ⅈ⎤
# ⎢-1, 1, - ─ - ────, - ─ + ────, ─ - ────, ─ + ────⎥
# ⎣         2    2      2    2    2    2    2    2  ⎦

# %%
#Látható, hogy a deriváltat nullára megoldva két értéket kapunk

# %%
x = np.linspace(0.9, 2, 100)

# %%
lennardjonesval = []
for i in x:
    
    lennardjonesval.append(lennardjonespotencial(i))

# %%
plt.plot(x, lennardjonesval)
plt.grid()

# %%
#Az egyensúlyi helyzetből való kitérést ábrázolva a tengelyeken:

lennardjonesval2 = []
for i in x:
    
    lennardjonesval2.append(lennardjonespotencial(abs(i+1)))

# %%
harmonikusptval2 = []
for i in x:
    
    harmonikusptval2.append(harmonikuspotencial(i))

# %%
plt.plot(x, lennardjonesval2)

# %%
plt.plot(x, lennardjonesval2)

plt.plot(x, harmonikusptval)
plt.grid()

# %%
# Ahhoz, hogy a potenciál görbülete azonos legyen, a ható erő nagyságának, vagyis a deriváltnak meg kell 
#egyeznie az x=1 pontban

# %%
lennardjonesero(1)
# Out:
# 0.0

# %%
x=symbols('x')
k=symbols('k')
x = -1
solve(-(12*V0*x0**12)/(x**13) + 12*V0*x0**6/(x**7)+k*x**4, k)
# Out:
# [0]

# %%
k=0

# %%
x = np.linspace(0.9, 2, 100)

# %%
harmonikuspt = []

lennardjonespt = []

lennardjoneseroertek = []
for i in x:
    
    harmonikuspt.append(harmonikuspotencial(i))
    
    lennardjonespt.append(lennardjonespotencial(i))
    
    lennardjoneseroertek.append(lennardjonesero(i))

# %%
plt.figure(figsize=(15, 10))

plt.plot(x, harmonikuspt)

plt.plot(x, lennardjonespt)

plt.plot(x, lennardjoneseroertek)

# %%
# x=1-ben mindkét függvény deriváltja zérus.

# %% [markdown]
# ## Alap 2. feladatrész
#
#
# Integráljuk a fentiek közül kettő rendszer, mégpedig a harmonikus és a Lennard-Jones potenciállal meghatározott oszcillátorok mozgásegyenletét a python scipy.integrate.RK45 csomagjának használatával! Ez egy adaptív Runge-Kutta eljárás, azaz a léptetés nagyságát hibabecslés alapján állítja be.
#
#
# ### a)
# Első lépésként írjuk fel  a mozgást leíró másodrendű differenciálegyenletet mindkét potenciál esetén elsőrendű differenciálegyenletek rendszereként!
# Ezután írjunk mindkét oszcillátorra egy-egy függvényt, amely a differenciálegyenlet rendszer jobb oldalán levő függvények
# neki megadott idő és állapot melletti értékeit visszaadja egy-egy tömbben!
#
#
# ### b)
# Ábrázoljuk a harmonikus és a Lennard-Jones potenciállal rendelkező rendszerek változóinak időfejlődését, a teljes energiát és a lépéshosszt  a scipy.integrate.RK45  adaptív  Runge-Kutta eljárás felhasználásával!
#
# Azt várjuk, hogy az  idő függvényében oszcilláló mozgást kapunk, ezért néhány periódus hosszan futtassuk az integrálást!  Mutassuk ki, hogy a  Lennard-Jones potenciál esetén  a lépéshossz jelentősen változik időben! Van-e lényeges lépéshossz változás a harmonikus oszcillátornál is?
#
# Egy kis segítség: a Lennard-Jones potenciál esetén indítsuk a rendszert az egyensúlyi helyzetből pozitív irányban $x_0/3$ értékkel kitérítve, kezdősebesség nélkül!
#
#
# A scipy.integrate.RK45 használata sokban hasonlít a fiznum1-ből tanult odeint használatához, azonban van néhány fontos különbség is. Egy részletesen kidolgozott egyszerű példát megtalálhatnak a fiznum2.public mappában (RK45-példa.ipynb), vagy letölthetik a gyakorlat honlapjáról, itt csak a leglényegesebb dolgokat foglaljuk össze röviden
# (lásd még https://docs.scipy.org/doc/scipy/reference/generated/scipy.integrate.RK45.html oldalt).
#
# Miután importáltuk a scipy.integrate csomagból az RK45-t, ilymódon tudjuk használni:
#
# rk45 = RK45( 'fun', 't0', 'y0', 't_bound', 'max_step=inf', 'rtol=0.001', 'atol=1e-06' )
#
# Itt a 'fun' függvényt fentebb, az a) részben  definiáltuk, 't0' a kezdő időpont, 'y0' a kezdő állapot.
# 'rtol' és 'atol' a megoldás relatív és abszolút pontosságát szabályozó paraméterek. A feladat megoldásakor
# a megfelelő pontosság eléréséhez az alapértelmezett rtol=0.001 értéket érdemes lecsökkenteni, pl  1e-5-re!
#
# Lényeges eltérés az odeint függvénytől, hogy az RK45 függvényhíváskor még csak egy objektumot kapunk eredményül. Ennek .step metódusát tudjuk az integrálási lépésekre használni, a .t, .y attribútumaiként pedig megkapjuk a változók értékeit. Tehát ha az RK45 eredményét a fentiek szerint eltároljuk, akkor a léptetés rk45.step() utasítással végezhető, az eredményeket pedig rk45.t, rk45.y értékeiként kapjuk meg.

# %%
# A differenciálegyenleteket még le kell írni

# %%
# a megoldás helye

# %pylab inline
from scipy.integrate import RK45
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/conda/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['Circle', 'ifft', 'cosh', 'pi', 'Line2D', 'sqrt', 'test', 'tan', 'partition', 'sin', 'poly', 'interactive', 'det', 'beta', 'sinc', 'plotting', 'minimum', 'prod', 'trace', 'sign', 're', 'binomial', 'Polygon', 'eye', 'exp', 'reshape', 'diff', 'plot', 'fft', 'invert', 'source', 'floor', 'log', 'Number', 'lcm', 'nan', 'cbrt', 'var', 'diag', 'cos', 'flatten', 'gcd', 'ones', 'roots', 'transpose', 'conjugate', 'tanh', 'take', 'sinh', 'solve', 'gamma', 'trunc', 'product', 'zeros', 'seterr', 'shape', 'maximum', 'vectorize']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
k = 1

# %% [markdown]
# A megoldandó differenciálegyenletek az a) részben a következők:

# %%
def harmonikusmozgas(t, ikszve):
    
    k=1
    
    xpont = ikszve[1]         #Itt adom meg, hogy x derivaltja a sebesség
    vpont = -k*ikszve[0]              #Itt adom meg a ható erő nagyságát
    
    
    return [xpont, vpont]

# %%
harmonikusmozgas(2,[2,3])
# Out:
# [3, -2]

# %%
t0=0
x0=1

kezdetix = 1
ikszve0=[kezdetix,0]  # kezdő időpont és állapot: 3 kitérés, és 0 sebesség

# %%
#A példából kimásolt és átírt kód

atol=1e-6; rtol=1e-7                          # Abszolút és relatív pontosság mgadása. ezek praktikusan jó értékek.
rk=RK45(harmonikusmozgas,t0,ikszve0,inf,atol=atol,rtol=rtol)  # A diffegyenlet rendszer megoldásának előkészítése:
           # Itt mondjuk meg a diffegyenletrendszert tartalmazó függvény nevét, és a kezdő időt és állapotot.
           # E függvényhívás hasonlít ahhoz, ahogy az odeint függvényt használtuk,
           # csakhogy az odeint egyből elvégezte a megoldást egy neki megadott időintervallumon,
           # ez az RK45 viszont csak egy objektumot ad vissza, amit eltárolunk, pl. *rk* néven.
           # Azt aztán az alábbi módon tudjuk léptetésre, és az állapot kiolvasására használni.
           # Másrészt 4. argumentumként egy időkorlátot lehet neki megadni, aminek a szerepe később lesz világos.
           # Még egy eltérés, hogy a *harmonikusmozgas* függvényben a *t* és az állapot változó sorendje ellentétes kell legyen
           # az odeint használata esetében szokásoshoz képest.
tlist=[]   # Ezekbe fogjuk gyűjteni az adatokat
ikszvelist=[]
ikszve=ikszve0     # a kezdő időpontot és állapotot betöltjük, hogy az első while lefutás is tudja ellenőrizni
#t1=380

while len(tlist)<=150:
#while ikszve[0]>1:         # addig léptessen, amíg az állapot zv vektorának z komponense pozitív
                       # így amikor leáll, az utolsó z érték 0 vagy negatív lesz már (és az lesz az első ilyen)
    t=rk.t             # Így olvassuk ki a pillanatnyi időt (kezdetben ez az RK45-nek megadott t0-t adja vissza)
    tlist.append(t)    # eltároljuk a listába
    ikszve=rk.y            # Az y objektumváltozóból lehet kiolvasni a pillanatnyi állapotvektort.
    ikszvelist.append(ikszve)  # Ezt is eltároljuk.
    rk.step()          # A step metódus pedig egy Runge-Kutta lépést végez.
                       # Ha túllépett az RK45 4. argumentumában megadott időkorláton, akkor nem léptet többet.
                       # Ha ilyen korlátozást nem akarunk, akkor ott inf-et adunk be.
# Látszik, hogy míg az odeint automatikusan végigszalad a neki megadott időintervallumon,
# a .step metódus egyszerre csak egy lépést végez. A lépés nagyságát ez is automatikusan választja, hibabecslés alapján.

# %%
ikszvearray=array(ikszvelist)          # A plot-beli indexeléshez kétindexes array-vé alakította.
plot(tlist,ikszvearray[:,0],"o-")  # Ábrázolta.
axhline(0,color="r")           # hogy látsszon a z=0 egyenes (lehet a grid() utasítással is)

# %%
lennardjonesero(-4/3)
# Out:
# -1.3167194724082951

# %%
def lennardjonesmozgas(t, ikszve2):
    
    
    xpont = ikszve2[1]         #Itt adom meg, hogy x derivaltja a sebesség
    vpont = lennardjonesero(ikszve2[0])              #Itt adom meg a ható erő nagyságát
    
    
    return [xpont, vpont]

# %%
lennardjonesmozgas(4,[1,3])
# Out:
# [3, 0.0]

# %%
x0
# Out:
# 1

# %%
t0=0
kezdetix = 1
#x0=x0/3
ikszve0=[kezdetix,1]  # kezdő időpont és állapot: 1/3 kitérés, és 0 sebesség

# %%
x0
# Out:
# 1

# %%
#Még hozzá kell nyúlni!!!!!!!!


#A példából kimásolt és átírt kód

atol=1e-6; rtol=1e-7                          # Abszolút és relatív pontosság mgadása. ezek praktikusan jó értékek.
rk=RK45(lennardjonesmozgas,t0,ikszve0,inf,atol=atol,rtol=rtol)  # A diffegyenlet rendszer megoldásának előkészítése:
           # Itt mondjuk meg a diffegyenletrendszert tartalmazó függvény nevét, és a kezdő időt és állapotot.
           # E függvényhívás hasonlít ahhoz, ahogy az odeint függvényt használtuk,
           # csakhogy az odeint egyből elvégezte a megoldást egy neki megadott időintervallumon,
           # ez az RK45 viszont csak egy objektumot ad vissza, amit eltárolunk, pl. *rk* néven.
           # Azt aztán az alábbi módon tudjuk léptetésre, és az állapot kiolvasására használni.
           # Másrészt 4. argumentumként egy időkorlátot lehet neki megadni, aminek a szerepe később lesz világos.
           # Még egy eltérés, hogy a *harmonikusmozgas* függvényben a *t* és az állapot változó sorendje ellentétes kell legyen
           # az odeint használata esetében szokásoshoz képest.
tlist=[]   # Ezekbe fogjuk gyűjteni az adatokat
ikszvelist=[]
ikszve=ikszve0     # a kezdő időpontot és állapotot betöltjük, hogy az első while lefutás is tudja ellenőrizni
#t1=380

while len(tlist)<=80:
#while ikszve[0]>1:         # addig léptessen, amíg az állapot zv vektorának z komponense pozitív
                       # így amikor leáll, az utolsó z érték 0 vagy negatív lesz már (és az lesz az első ilyen)
    t=rk.t             # Így olvassuk ki a pillanatnyi időt (kezdetben ez az RK45-nek megadott t0-t adja vissza)
    tlist.append(t)    # eltároljuk a listába
    ikszve=rk.y            # Az y objektumváltozóból lehet kiolvasni a pillanatnyi állapotvektort.
    ikszvelist.append(ikszve)  # Ezt is eltároljuk.
    rk.step()          # A step metódus pedig egy Runge-Kutta lépést végez.
                       # Ha túllépett az RK45 4. argumentumában megadott időkorláton, akkor nem léptet többet.
                       # Ha ilyen korlátozást nem akarunk, akkor ott inf-et adunk be.
# Látszik, hogy míg az odeint automatikusan végigszalad a neki megadott időintervallumon,
# a .step metódus egyszerre csak egy lépést végez. A lépés nagyságát ez is automatikusan választja, hibabecslés alapján.
# Out:
# <ipython-input-12-9163dae2c796>:3: RuntimeWarning: overflow encountered in double_scalars
#   ero = -(12*V0*x0**12)/(x**13) + 12*V0*x0**6/(x**7)

# %%
ikszvearray=array(ikszvelist)          # A plot-beli indexeléshez kétindexes array-vé alakította.

plt.figure(figsize=(15, 10))
plot(tlist,ikszvearray,"o-")  # Ábrázolta.
axhline(0,color="r")           # hogy látsszon a z=0 egyenes (lehet a grid() utasítással is)

# %%
tlist[-1]
# Out:
# 1.2244924181055491e+61

# %%
elsotlist = tlist

# %% [markdown]
# ## Teljes 3. feladatrész
#
# Vizsgáljuk a Lennard-Jones-potenciál esetén, hogy az adaptív, a nemadaptív Runge-Kutta és az Euler módszer hibája hogyan viszonyul egymáshoz, ha azonos lépésszámot próbálunk elérni! Mivel a rendszer energiája elméletileg konstans, az energiának a kezdeti értéktől való eltérését használhatjuk a hiba jelzésére, azt ábrázoljuk az idő függvényében néhány perióduson keresztül!
#
# Az egyes léptetésekben az adaptív eljárással azonos, de ugyanakkor nem adaptív megoldást úgy tudunk létrehozni, hogy az RK45 eljárás használatakor a hibahatárokat (az atol és rtol nevű opcionális paramétereket) 0.1-re állítjuk, ekkor az a hibabecslése alapján viszonylag nagy lépéseket használna. Ugyanakkor a lépések nagyságát a max_step nevű opcionális paraméterrel korlátozva gyakorlatilag kikapcsoljuk a saját lépésköz szabályzását. Használjuk itt lépésköznek azt az értéket, amivel ugyanannyi lépés jön létre az eddig használt időintervallumon, mint amennyi az adaptív esetben volt!
#
# Az Euler módszerre írjunk egyszerű for ciklust, vagy függvényt, amiben az előbbi lépésközt használjuk! Ábrázoljuk a három módszerrel az $x$ koordinátára kapott eredményeket egy ábrában, egy másikban pedig az energia megváltozását a kezdetihez képest. Amennyiben valamelyik eljárás nem adna oszcilláló megoldást, annál addig csökkentsük a lépésközt 10-ed, 100-ad részére, amíg oszcilláló lesz! Ha pedig az energiaváltozás ábráján nem látszik egyszerre a 3 esetben az energiaváltozás, akkor használjunk logaritmikus skálát.

# %%
# adaptív, nonadaptív, Euler hiba öszehasonlítása az energia értékének változásában

# %%
Energianull = lennardjonespotencial(x0)+1/2*1*ikszve0[1]**2

# %%
Energianull
# Out:
# -0.5

# %%
#Adaptív Runge-kutta módszer

# %%
sebessegek = [element[1] for element in ikszvelist]

# %%
helyek = [element[0] for element in ikszvelist]

# %%
len(sebessegek)
# Out:
# 81

# %%
max(sebessegek)
# Out:
# 1.7320511327283223

# %%
energiaertekek = []

# %%
for i in range(0, len(ikszvelist)):
    
    energia = lennardjonespotencial(helyek[i])+1/2*1*sebessegek[i]**2
    
    energiaertekek.append(energia)
# Out:
# <ipython-input-10-20cb57bf76d7>:3: RuntimeWarning: overflow encountered in double_scalars
#   lennardjones  = V0*((x0**12)/(x**12)-2*((x0**6/x**6)))

# %%
energiakulonbseg = []

for i in energiaertekek:
    
    energiakulonbseg.append(i-Energianull)

# %%
len(elsotlist)
# Out:
# 81

# %%
elsotlist[-1]
# Out:
# 1.2244924181055491e+61

# %%
plt.plot(elsotlist[:100], energiakulonbseg[:100])

# %%
lennardjonesero(1)
# Out:
# 0.0

# %%
x0
# Out:
# 1

# %%
#A nemadaptív Runge-Kutta módszer megvalósítása:

# %%
t0=0
kezdetix= 4/3
#x0 = x0/3
ikszve0=[kezdetix,0]

# %%
#kezdetix

# %%
atol=0.1; rtol=0.1                          # Abszolút és relatív pontosság mgadása. ezek praktikusan jó értékek.

rk=RK45(lennardjonesmozgas,t0,ikszve0,inf, max_step=0.006713123335, atol=atol,rtol=rtol)  # A diffegyenlet rendszer megoldásának előkészítése:
           # Itt mondjuk meg a diffegyenletrendszert tartalmazó függvény nevét, és a kezdő időt és állapotot.
           # E függvényhívás hasonlít ahhoz, ahogy az odeint függvényt használtuk,
           # csakhogy az odeint egyből elvégezte a megoldást egy neki megadott időintervallumon,
           # ez az RK45 viszont csak egy objektumot ad vissza, amit eltárolunk, pl. *rk* néven.
           # Azt aztán az alábbi módon tudjuk léptetésre, és az állapot kiolvasására használni.
           # Másrészt 4. argumentumként egy időkorlátot lehet neki megadni, aminek a szerepe később lesz világos.
           # Még egy eltérés, hogy a *harmonikusmozgas* függvényben a *t* és az állapot változó sorendje ellentétes kell legyen
           # az odeint használata esetében szokásoshoz képest.
masodiktlist=[]   # Ezekbe fogjuk gyűjteni az adatokat
ikszvelist=[]
ikszve=ikszve0     # a kezdő időpontot és állapotot betöltjük, hogy az első while lefutás is tudja ellenőrizni
#t1=380

#while tlist[-1]<=10.7841385194112:
while len(masodiktlist)<1601:
    
    
#while ikszve[0]<100:         # addig léptessen, amíg az állapot zv vektorának z komponense pozitív
                       # így amikor leáll, az utolsó z érték 0 vagy negatív lesz már (és az lesz az első ilyen)
    t=rk.t             # Így olvassuk ki a pillanatnyi időt (kezdetben ez az RK45-nek megadott t0-t adja vissza)
    masodiktlist.append(t)    # eltároljuk a listába
    ikszve=rk.y            # Az y objektumváltozóból lehet kiolvasni a pillanatnyi állapotvektort.
    ikszvelist.append(ikszve)  # Ezt is eltároljuk.
    #if tlist[-1]<11:
    rk.step()          # A step metódus pedig egy Runge-Kutta lépést végez.
                       # Ha túllépett az RK45 4. argumentumában megadott időkorláton, akkor nem léptet többet.
                       # Ha ilyen korlátozást nem akarunk, akkor ott inf-et adunk be.
# Látszik, hogy míg az odeint automatikusan végigszalad a neki megadott időintervallumon,
# a .step metódus egyszerre csak egy lépést végez. A lépés nagyságát ez is automatikusan választja, hibabecslés alapján.

# %%
len(masodiktlist)
# Out:
# 1601

# %%
len(ikszvearray)
# Out:
# 81

# %%
masodiktlist
# Out:
# [0, 0.006713123335, 0.01342624667, 0.020139370004999997, 0.02685249334, 0.0335
# 65616675, 0.04027874001, 0.046991863345, 0.053704986680000004, 0.0604181100150
# 00005, 0.06713123335, 0.073844356685, 0.08055748002, 0.087270603355, 0.0939837
# 2669, 0.100696850025, 0.10740997336000001, 0.11412309669500001, 0.120836220030
# 00001, 0.127549343365, 0.1342624667, 0.140975590035, 0.14768871336999997, 0.15
# 440183670499996, 0.16111496003999995, 0.16782808337499994, 0.17454120670999992
# , 0.1812543300449999, 0.1879674533799999, 0.1946805767149999, 0.20139370004999
# 987, 0.20810682338499986, 0.21481994671999985, 0.22153307005499984, 0.22824619
# 338999982, 0.2349593167249998, 0.2416724400599998, 0.2483855633949998, 0.25509
# 86867299998, 0.2618118100649998, 0.26852493339999983, 0.27523805673499985, 0.2
# 8195118006999986, 0.2886643034049999, 0.2953774267399999, 0.3020905500749999,
# 0.3088036734099999, 0.31551679674499994, 0.32222992007999995, 0.32894304341499
# 997, 0.33565616675, 0.342369290085, 0.34908241342, 0.35579553675500003, 0.3625
# 0866009000005, 0.36922178342500006, 0.3759349067600001, 0.3826480300950001, 0.
# 3893611534300001, 0.3960742767650001, 0.40278740010000014, 0.40950052343500015
# , 0.41621364677000017, 0.4229267701050002, 0.4296398934400002, 0.4363530167750
# 002, 0.44306614011000023, 0.44977926344500024, 0.45649238678000026, 0.46320551
# 01150003, 0.4699186334500003, 0.4766317567850003, 0.4833448801200003, 0.490058
# 00345500033, 0.49677112679000035, 0.5034842501250003, 0.5101973734600003, 0.51
# 69104967950002, 0.5236236201300002, 0.5303367434650001, 0.5370498668000001, 0.
# 5437629901350001, 0.55047611347, 0.557189236805, 0.56390236014, 0.570615483474
# 9999, 0.5773286068099999, 0.5840417301449998, 0.5907548534799998, 0.5974679768
# 149997, 0.6041811001499997, 0.6108942234849997, 0.6176073468199996, 0.62432047
# 01549996, 0.6310335934899995, 0.6377467168249995, 0.6444598401599995, 0.651172
# 9634949994, 0.6578860868299994, 0.6645992101649993, 0.6713123334999993, 0.6780
# 254568349993, 0.6847385801699992, 0.6914517035049992, 0.6981648268399991, 0.70
# 48779501749991, 0.7115910735099991, 0.718304196844999, 0.725017320179999, 0.73
# 17304435149989, 0.7384435668499989, 0.7451566901849989, 0.7518698135199988, 0.
# 7585829368549988, 0.7652960601899987, 0.7720091835249987, 0.7787223068599987,
# 0.7854354301949986, 0.7921485535299986, 0.7988616768649985, 0.8055748001999985
# , 0.8122879235349985, 0.8190010468699984, 0.8257141702049984, 0.83242729353999
# 83, 0.8391404168749983, 0.8458535402099983, 0.8525666635449982, 0.859279786879
# 9982, 0.8659929102149981, 0.8727060335499981, 0.879419156884998, 0.88613228021
# 9998, 0.892845403554998, 0.8995585268899979, 0.9062716502249979, 0.91298477355
# 99979, 0.9196978968949978, 0.9264110202299978, 0.9331241435649977, 0.939837266
# 8999977, 0.9465503902349977, 0.9532635135699976, 0.9599766369049976, 0.9666897
# 602399975, 0.9734028835749975, 0.9801160069099975, 0.9868291302449974, 0.99354
# 22535799974, 1.0002553769149973, 1.0069685002499973, 1.0136816235849972, 1.020
# 3947469199972, 1.0271078702549972, 1.0338209935899971, 1.040534116924997, 1.04
# 7247240259997, 1.053960363594997, 1.060673486929997, 1.067386610264997, 1.0740
# 997335999969, 1.0808128569349968, 1.0875259802699968, 1.0942391036049968, 1.10
# 09522269399967, 1.1076653502749967, 1.1143784736099966, 1.1210915969449966, 1.
# 1278047202799966, 1.1345178436149965, 1.1412309669499965, 1.1479440902849964,
# 1.1546572136199964, 1.1613703369549964, 1.1680834602899963, 1.1747965836249963
# , 1.1815097069599962, 1.1882228302949962, 1.1949359536299962, 1.20164907696499
# 61, 1.208362200299996, 1.215075323634996, 1.221788446969996, 1.228501570304996
# , 1.235214693639996, 1.2419278169749959, 1.2486409403099958, 1.255354063644995
# 8, 1.2620671869799958, 1.2687803103149957, 1.2754934336499957, 1.2822065569849
# 956, 1.2889196803199956, 1.2956328036549956, 1.3023459269899955, 1.30905905032
# 49955, 1.3157721736599954, 1.3224852969949954, 1.3291984203299954, 1.335911543
# 6649953, 1.3426246669999953, 1.3493377903349952, 1.3560509136699952, 1.3627640
# 370049952, 1.3694771603399951, 1.376190283674995, 1.382903407009995, 1.3896165
# 30344995, 1.396329653679995, 1.403042777014995, 1.4097559003499949, 1.41646902
# 36849948, 1.4231821470199948, 1.4298952703549948, 1.4366083936899947, 1.443321
# 5170249947, 1.4500346403599946, 1.4567477636949946, 1.4634608870299946, 1.4701
# 740103649945, 1.4768871336999945, 1.4836002570349944, 1.4903133803699944, 1.49
# 70265037049943, 1.5037396270399943, 1.5104527503749943, 1.5171658737099942, 1.
# 5238789970449942, 1.5305921203799941, 1.537305243714994, 1.544018367049994, 1.
# 550731490384994, 1.557444613719994, 1.564157737054994, 1.570870860389994, 1.57
# 75839837249939, 1.5842971070599938, 1.5910102303949938, 1.5977233537299937, 1.
# 6044364770649937, 1.6111496003999937, 1.6178627237349936, 1.6245758470699936,
# 1.6312889704049935, 1.6380020937399935, 1.6447152170749935, 1.6514283404099934
# , 1.6581414637449934, 1.6648545870799933, 1.6715677104149933, 1.67828083374999
# 33, 1.6849939570849932, 1.6917070804199932, 1.6984202037549931, 1.705133327089
# 993, 1.711846450424993, 1.718559573759993, 1.725272697094993, 1.73198582042999
# 3, 1.738698943764993, 1.7454120670999929, 1.7521251904349928, 1.75883831376999
# 28, 1.7655514371049927, 1.7722645604399927, 1.7789776837749927, 1.785690807109
# 9926, 1.7924039304449926, 1.7991170537799925, 1.8058301771149925, 1.8125433004
# 499925, 1.8192564237849924, 1.8259695471199924, 1.8326826704549923, 1.83939579
# 37899923, 1.8461089171249923, 1.8528220404599922, 1.8595351637949922, 1.866248
# 2871299921, 1.872961410464992, 1.879674533799992, 1.886387657134992, 1.8931007
# 80469992, 1.899813903804992, 1.906527027139992, 1.9132401504749919, 1.91995327
# 38099918, 1.9266663971449918, 1.9333795204799917, 1.9400926438149917, 1.946805
# 7671499917, 1.9535188904849916, 1.9602320138199916, 1.9669451371549915, 1.9736
# 582604899915, 1.9803713838249914, 1.9870845071599914, 1.9937976304949914, 2.00
# 05107538299916, 2.0072238771649915, 2.0139370004999915, 2.0206501238349914, 2.
# 0273632471699914, 2.0340763705049913, 2.0407894938399913, 2.0475026171749913,
# 2.0542157405099912, 2.060928863844991, 2.067641987179991, 2.074355110514991, 2
# .081068233849991, 2.087781357184991, 2.094494480519991, 2.101207603854991, 2.1
# 07920727189991, 2.114633850524991, 2.121346973859991, 2.128060097194991, 2.134
# 7732205299907, 2.1414863438649907, 2.1481994671999907, 2.1549125905349906, 2.1
# 616257138699906, 2.1683388372049905, 2.1750519605399905, 2.1817650838749905, 2
# .1884782072099904, 2.1951913305449904, 2.2019044538799903, 2.2086175772149903,
#  2.2153307005499903, 2.22204382388499, 2.22875694721999, 2.23547007055499, 2.2
# 4218319388999, 2.24889631722499, 2.25560944055999, 2.26232256389499, 2.2690356
# 8722999, 2.27574881056499, 2.28246193389999, 2.28917505723499, 2.2958881805699
# 9, 2.3026013039049897, 2.3093144272399897, 2.3160275505749897, 2.3227406739099
# 896, 2.3294537972449896, 2.3361669205799895, 2.3428800439149895, 2.34959316724
# 99895, 2.3563062905849894, 2.3630194139199894, 2.3697325372549893, 2.376445660
# 5899893, 2.3831587839249893, 2.389871907259989, 2.396585030594989, 2.403298153
# 929989, 2.410011277264989, 2.416724400599989, 2.423437523934989, 2.43015064726
# 9989, 2.436863770604989, 2.443576893939989, 2.450290017274989, 2.4570031406099
# 89, 2.4637162639449888, 2.4704293872799887, 2.4771425106149887, 2.483855633949
# 9887, 2.4905687572849886, 2.4972818806199886, 2.5039950039549885, 2.5107081272
# 899885, 2.5174212506249884, 2.5241343739599884, 2.5308474972949884, 2.53756062
# 06299883, 2.5442737439649883, 2.5509868672999882, 2.557699990634988, 2.5644131
# 13969988, 2.571126237304988, 2.577839360639988, 2.584552483974988, 2.591265607
# 309988, 2.597978730644988, 2.604691853979988, 2.611404977314988, 2.61811810064
# 9988, 2.624831223984988, 2.6315443473199878, 2.6382574706549877, 2.64497059398
# 99877, 2.6516837173249876, 2.6583968406599876, 2.6651099639949876, 2.671823087
# 3299875, 2.6785362106649875, 2.6852493339999874, 2.6919624573349874, 2.6986755
# 806699874, 2.7053887040049873, 2.7121018273399873, 2.7188149506749872, 2.72552
# 8074009987, 2.732241197344987, 2.738954320679987, 2.745667444014987, 2.7523805
# 67349987, 2.759093690684987, 2.765806814019987, 2.772519937354987, 2.779233060
# 689987, 2.785946184024987, 2.792659307359987, 2.7993724306949868, 2.8060855540
# 299867, 2.8127986773649867, 2.8195118006999866, 2.8262249240349866, 2.83293804
# 73699866, 2.8396511707049865, 2.8463642940399865, 2.8530774173749864, 2.859790
# 5407099864, 2.8665036640449864, 2.8732167873799863, 2.8799299107149863, 2.8866
# 430340499862, 2.893356157384986, 2.900069280719986, 2.906782404054986, 2.91349
# 5527389986, 2.920208650724986, 2.926921774059986, 2.933634897394986, 2.9403480
# 20729986, 2.947061144064986, 2.953774267399986, 2.960487390734986, 2.967200514
# 0699858, 2.9739136374049857, 2.9806267607399857, 2.9873398840749856, 2.9940530
# 074099856, 3.0007661307449855, 3.0074792540799855, 3.0141923774149855, 3.02090
# 55007499854, 3.0276186240849854, 3.0343317474199853, 3.0410448707549853, 3.047
# 7579940899853, 3.0544711174249852, 3.061184240759985, 3.067897364094985, 3.074
# 610487429985, 3.081323610764985, 3.088036734099985, 3.094749857434985, 3.10146
# 2980769985, 3.108176104104985, 3.114889227439985, 3.121602350774985, 3.1283154
# 74109985, 3.1350285974449847, 3.1417417207799847, 3.1484548441149847, 3.155167
# 9674499846, 3.1618810907849846, 3.1685942141199845, 3.1753073374549845, 3.1820
# 204607899845, 3.1887335841249844, 3.1954467074599844, 3.2021598307949843, 3.20
# 88729541299843, 3.2155860774649843, 3.222299200799984, 3.229012324134984, 3.23
# 5725447469984, 3.242438570804984, 3.249151694139984, 3.255864817474984, 3.2625
# 77940809984, 3.269291064144984, 3.276004187479984, 3.282717310814984, 3.289430
# 434149984, 3.2961435574849838, 3.3028566808199837, 3.3095698041549837, 3.31628
# 29274899837, 3.3229960508249836, 3.3297091741599836, 3.3364222974949835, 3.343
# 1354208299835, 3.3498485441649835, 3.3565616674999834, 3.3632747908349834, 3.3
# 699879141699833, 3.3767010375049833, 3.3834141608399833, 3.390127284174983, 3.
# 396840407509983, 3.403553530844983, 3.410266654179983, 3.416979777514983, 3.42
# 3692900849983, 3.430406024184983, 3.437119147519983, 3.443832270854983, 3.4505
# 45394189983, 3.457258517524983, 3.4639716408599828, 3.4706847641949827, 3.4773
# 978875299827, 3.4841110108649826, 3.4908241341999826, 3.4975372575349826, 3.50
# 42503808699825, 3.5109635042049825, 3.5176766275399824, 3.5243897508749824, 3.
# 5311028742099824, 3.5378159975449823, 3.5445291208799823, 3.5512422442149822,
# 3.557955367549982, 3.564668490884982, 3.571381614219982, 3.578094737554982, 3.
# 584807860889982, 3.591520984224982, 3.598234107559982, 3.604947230894982, 3.61
# 1660354229982, 3.618373477564982, 3.625086600899982, 3.6317997242349818, 3.638
# 5128475699817, 3.6452259709049817, 3.6519390942399816, 3.6586522175749816, 3.6
# 653653409099816, 3.6720784642449815, 3.6787915875799815, 3.6855047109149814, 3
# .6922178342499814, 3.6989309575849814, 3.7056440809199813, 3.7123572042549813,
#  3.7190703275899812, 3.725783450924981, 3.732496574259981, 3.739209697594981,
# 3.745922820929981, 3.752635944264981, 3.759349067599981, 3.766062190934981, 3.
# 772775314269981, 3.779488437604981, 3.786201560939981, 3.792914684274981, 3.79
# 96278076099808, 3.8063409309449807, 3.8130540542799807, 3.8197671776149806, 3.
# 8264803009499806, 3.8331934242849806, 3.8399065476199805, 3.8466196709549805,
# 3.8533327942899804, 3.8600459176249804, 3.8667590409599804, 3.8734721642949803
# , 3.8801852876299803, 3.8868984109649802, 3.89361153429998, 3.90032465763498,
# 3.90703778096998, 3.91375090430498, 3.92046402763998, 3.92717715097498, 3.9338
# 9027430998, 3.94060339764498, 3.94731652097998, 3.95402964431498, 3.9607427676
# 4998, 3.9674558909849797, 3.9741690143199797, 3.9808821376549797, 3.9875952609
# 899796, 3.9943083843249796, 4.0010215076599795, 4.00773463099498, 4.0144477543
# 2998, 4.021160877664981, 4.027874000999981, 4.034587124334982, 4.0413002476699
# 82, 4.048013371004982, 4.054726494339983, 4.061439617674983, 4.068152741009984
# , 4.074865864344984, 4.081578987679984, 4.088292111014985, 4.095005234349985,
# 4.101718357684986, 4.108431481019986, 4.115144604354986, 4.121857727689987, 4.
# 128570851024987, 4.135283974359988, 4.141997097694988, 4.148710221029988, 4.15
# 5423344364989, 4.162136467699989, 4.16884959103499, 4.17556271436999, 4.182275
# 8377049905, 4.188988961039991, 4.195702084374991, 4.202415207709992, 4.2091283
# 31044992, 4.2158414543799925, 4.222554577714993, 4.229267701049993, 4.23598082
# 4384994, 4.242693947719994, 4.2494070710549945, 4.256120194389995, 4.262833317
# 724995, 4.269546441059996, 4.276259564394996, 4.2829726877299965, 4.2896858110
# 64997, 4.296398934399997, 4.303112057734998, 4.309825181069998, 4.316538304404
# 9985, 4.323251427739999, 4.329964551074999, 4.33667767441, 4.343390797745, 4.3
# 501039210800005, 4.356817044415001, 4.363530167750001, 4.370243291085002, 4.37
# 6956414420002, 4.383669537755003, 4.390382661090003, 4.397095784425003, 4.4038
# 08907760004, 4.410522031095004, 4.417235154430005, 4.423948277765005, 4.430661
# 401100005, 4.437374524435006, 4.444087647770006, 4.450800771105007, 4.45751389
# 4440007, 4.464227017775007, 4.470940141110008, 4.477653264445008, 4.4843663877
# 80009, 4.491079511115009, 4.497792634450009, 4.50450575778501, 4.5112188811200
# 1, 4.517932004455011, 4.524645127790011, 4.5313582511250114, 4.538071374460012
# , 4.544784497795012, 4.551497621130013, 4.558210744465013, 4.5649238678000135,
#  4.571636991135014, 4.578350114470014, 4.585063237805015, 4.591776361140015, 4
# .5984894844750155, 4.605202607810016, 4.611915731145016, 4.618628854480017, 4.
# 625341977815017, 4.6320551011500175, 4.638768224485018, 4.645481347820018, 4.6
# 52194471155019, 4.658907594490019, 4.6656207178250195, 4.67233384116002, 4.679
# 04696449502, 4.685760087830021, 4.692473211165021, 4.6991863345000215, 4.70589
# 9457835022, 4.712612581170022, 4.719325704505023, 4.726038827840023, 4.7327519
# 51175024, 4.739465074510024, 4.746178197845024, 4.752891321180025, 4.759604444
# 515025, 4.766317567850026, 4.773030691185026, 4.779743814520026, 4.78645693785
# 5027, 4.793170061190027, 4.799883184525028, 4.806596307860028, 4.8133094311950
# 28, 4.820022554530029, 4.826735677865029, 4.83344880120003, 4.84016192453503,
# 4.84687504787003, 4.853588171205031, 4.860301294540031, 4.867014417875032, 4.8
# 73727541210032, 4.8804406645450324, 4.887153787880033, 4.893866911215033, 4.90
# 0580034550034, 4.907293157885034, 4.9140062812200345, 4.920719404555035, 4.927
# 432527890035, 4.934145651225036, 4.940858774560036, 4.9475718978950365, 4.9542
# 85021230037, 4.960998144565037, 4.967711267900038, 4.974424391235038, 4.981137
# 5145700385, 4.987850637905039, 4.994563761240039, 5.00127688457504, 5.00799000
# 791004, 5.0147031312450405, 5.021416254580041, 5.028129377915041, 5.0348425012
# 50042, 5.041555624585042, 5.0482687479200425, 5.054981871255043, 5.06169499459
# 0043, 5.068408117925044, 5.075121241260044, 5.081834364595045, 5.0885474879300
# 45, 5.095260611265045, 5.101973734600046, 5.108686857935046, 5.115399981270047
# , 5.122113104605047, 5.128826227940047, 5.135539351275048, 5.142252474610048,
# 5.148965597945049, 5.155678721280049, 5.162391844615049, 5.16910496795005, 5.1
# 7581809128505, 5.182531214620051, 5.189244337955051, 5.195957461290051, 5.2026
# 70584625052, 5.209383707960052, 5.216096831295053, 5.222809954630053, 5.229523
# 0779650534, 5.236236201300054, 5.242949324635054, 5.249662447970055, 5.2563755
# 71305055, 5.2630886946400555, 5.269801817975056, 5.276514941310056, 5.28322806
# 4645057, 5.289941187980057, 5.2966543113150575, 5.303367434650058, 5.310080557
# 985058, 5.316793681320059, 5.323506804655059, 5.3302199279900595, 5.3369330513
# 2506, 5.34364617466006, 5.350359297995061, 5.357072421330061, 5.36378554466506
# 15, 5.370498668000062, 5.377211791335062, 5.383924914670063, 5.390638038005063
# , 5.3973511613400635, 5.404064284675064, 5.410777408010064, 5.417490531345065,
#  5.424203654680065, 5.430916778015066, 5.437629901350066, 5.444343024685066, 5
# .451056148020067, 5.457769271355067, 5.464482394690068, 5.471195518025068, 5.4
# 77908641360068, 5.484621764695069, 5.491334888030069, 5.49804801136507, 5.5047
# 6113470007, 5.51147425803507, 5.518187381370071, 5.524900504705071, 5.53161362
# 8040072, 5.538326751375072, 5.545039874710072, 5.551752998045073, 5.5584661213
# 80073, 5.565179244715074, 5.571892368050074, 5.5786054913850744, 5.58531861472
# 0075, 5.592031738055075, 5.598744861390076, 5.605457984725076, 5.6121711080600
# 765, 5.618884231395077, 5.625597354730077, 5.632310478065078, 5.63902360140007
# 8, 5.6457367247350785, 5.652449848070079, 5.659162971405079, 5.66587609474008,
#  5.67258921807508, 5.6793023414100805, 5.686015464745081, 5.692728588080081, 5
# .699441711415082, 5.706154834750082, 5.7128679580850825, 5.719581081420083, 5.
# 726294204755083, 5.733007328090084, 5.739720451425084, 5.7464335747600845, 5.7
# 53146698095085, 5.759859821430085, 5.766572944765086, 5.773286068100086, 5.779
# 999191435087, 5.786712314770087, 5.793425438105087, 5.800138561440088, 5.80685
# 1684775088, 5.813564808110089, 5.820277931445089, 5.826991054780089, 5.8337041
# 7811509, 5.84041730145009, 5.847130424785091, 5.853843548120091, 5.86055667145
# 5091, 5.867269794790092, 5.873982918125092, 5.880696041460093, 5.8874091647950
# 93, 5.894122288130093, 5.900835411465094, 5.907548534800094, 5.914261658135095
# , 5.920974781470095, 5.927687904805095, 5.934401028140096, 5.941114151475096,
# 5.947827274810097, 5.954540398145097, 5.9612535214800975, 5.967966644815098, 5
# .974679768150098, 5.981392891485099, 5.988106014820099, 5.9948191381550995, 6.
# 0015322614901, 6.0082453848251, 6.014958508160101, 6.021671631495101, 6.028384
# 7548301015, 6.035097878165102, 6.041811001500102, 6.048524124835103, 6.0552372
# 48170103, 6.0619503715051035, 6.068663494840104, 6.075376618175104, 6.08208974
# 1510105, 6.088802864845105, 6.0955159881801055, 6.102229111515106, 6.108942234
# 850106, 6.115655358185107, 6.122368481520107, 6.129081604855108, 6.13579472819
# 0108, 6.142507851525108, 6.149220974860109, 6.155934098195109, 6.1626472215301
# 1, 6.16936034486511, 6.17607346820011, 6.182786591535111, 6.189499714870111, 6
# .196212838205112, 6.202925961540112, 6.209639084875112, 6.216352208210113, 6.2
# 23065331545113, 6.229778454880114, 6.236491578215114, 6.243204701550114, 6.249
# 917824885115, 6.256630948220115, 6.263344071555116, 6.270057194890116, 6.27677
# 0318225116, 6.283483441560117, 6.290196564895117, 6.296909688230118, 6.3036228
# 11565118, 6.3103359349001185, 6.317049058235119, 6.323762181570119, 6.33047530
# 490512, 6.33718842824012, 6.3439015515751205, 6.350614674910121, 6.35732779824
# 5121, 6.364040921580122, 6.370754044915122, 6.3774671682501225, 6.384180291585
# 123, 6.390893414920123, 6.397606538255124, 6.404319661590124, 6.41103278492512
# 45, 6.417745908260125, 6.424459031595125, 6.431172154930126, 6.437885278265126
# , 6.4445984016001265, 6.451311524935127, 6.458024648270127, 6.464737771605128,
#  6.471450894940128, 6.4781640182751286, 6.484877141610129, 6.491590264945129,
# 6.49830338828013, 6.50501651161513, 6.511729634950131, 6.518442758285131, 6.52
# 5155881620131, 6.531869004955132, 6.538582128290132, 6.545295251625133, 6.5520
# 08374960133, 6.558721498295133, 6.565434621630134, 6.572147744965134, 6.578860
# 868300135, 6.585573991635135, 6.592287114970135, 6.599000238305136, 6.60571336
# 1640136, 6.612426484975137, 6.619139608310137, 6.625852731645137, 6.6325658549
# 80138, 6.639278978315138, 6.645992101650139, 6.652705224985139, 6.659418348320
# 1395, 6.66613147165514, 6.67284459499014, 6.679557718325141, 6.686270841660141
# , 6.6929839649951415, 6.699697088330142, 6.706410211665142, 6.713123335000143,
#  6.719836458335143, 6.7265495816701435, 6.733262705005144, 6.739975828340144,
# 6.746688951675145, 6.753402075010145, 6.7601151983451455, 6.766828321680146, 6
# .773541445015146, 6.780254568350147, 6.786967691685147, 6.7936808150201475, 6.
# 800393938355148, 6.807107061690148, 6.813820185025149, 6.820533308360149, 6.82
# 72464316951496, 6.83395955503015, 6.84067267836515, 6.847385801700151, 6.85409
# 8925035151, 6.860812048370152, 6.867525171705152, 6.874238295040152, 6.8809514
# 18375153, 6.887664541710153, 6.894377665045154, 6.901090788380154, 6.907803911
# 715154, 6.914517035050155, 6.921230158385155, 6.927943281720156, 6.93465640505
# 5156, 6.941369528390156, 6.948082651725157, 6.954795775060157, 6.9615088983951
# 58, 6.968222021730158, 6.974935145065158, 6.981648268400159, 6.988361391735159
# , 6.99507451507016, 7.00178763840516, 7.0085007617401605, 7.015213885075161, 7
# .021927008410161, 7.028640131745162, 7.035353255080162, 7.0420663784151625, 7.
# 048779501750163, 7.055492625085163, 7.062205748420164, 7.068918871755164, 7.07
# 56319950901645, 7.082345118425165, 7.089058241760165, 7.095771365095166, 7.102
# 484488430166, 7.1091976117651665, 7.115910735100167, 7.122623858435167, 7.1293
# 36981770168, 7.136050105105168, 7.1427632284401685, 7.149476351775169, 7.15618
# 9475110169, 7.16290259844517, 7.16961572178017, 7.1763288451151706, 7.18304196
# 8450171, 7.189755091785171, 7.196468215120172, 7.203181338455172, 7.2098944617
# 90173, 7.216607585125173, 7.223320708460173, 7.230033831795174, 7.236746955130
# 174, 7.243460078465175, 7.250173201800175, 7.256886325135175, 7.26359944847017
# 6, 7.270312571805176, 7.277025695140177, 7.283738818475177, 7.290451941810177,
#  7.297165065145178, 7.303878188480178, 7.310591311815179, 7.317304435150179, 7
# .324017558485179, 7.33073068182018, 7.33744380515518, 7.344156928490181, 7.350
# 870051825181, 7.3575831751601815, 7.364296298495182, 7.371009421830182, 7.3777
# 22545165183, 7.384435668500183, 7.3911487918351835, 7.397861915170184, 7.40457
# 5038505184, 7.411288161840185, 7.418001285175185, 7.4247144085101855, 7.431427
# 531845186, 7.438140655180186, 7.444853778515187, 7.451566901850187, 7.45828002
# 51851875, 7.464993148520188, 7.471706271855188, 7.478419395190189, 7.485132518
# 525189, 7.4918456418601895, 7.49855876519519, 7.50527188853019, 7.511985011865
# 191, 7.518698135200191, 7.5254112585351915, 7.532124381870192, 7.5388375052051
# 92, 7.545550628540193, 7.552263751875193, 7.558976875210194, 7.565689998545194
# , 7.572403121880194, 7.579116245215195, 7.585829368550195, 7.592542491885196,
# 7.599255615220196, 7.605968738555196, 7.612681861890197, 7.619394985225197, 7.
# 626108108560198, 7.632821231895198, 7.639534355230198, 7.646247478565199, 7.65
# 2960601900199, 7.6596737252352, 7.6663868485702, 7.6730999719052, 7.6798130952
# 40201, 7.686526218575201, 7.693239341910202, 7.699952465245202, 7.706665588580
# 2025, 7.713378711915203, 7.720091835250203, 7.726804958585204, 7.7335180819202
# 04, 7.7402312052552045, 7.746944328590205, 7.753657451925205, 7.76037057526020
# 6, 7.767083698595206, 7.7737968219302065, 7.780509945265207, 7.787223068600207
# , 7.793936191935208, 7.800649315270208, 7.8073624386052085, 7.814075561940209,
#  7.820788685275209, 7.82750180861021, 7.83421493194521, 7.8409280552802105, 7.
# 847641178615211, 7.854354301950211, 7.861067425285212, 7.867780548620212, 7.87
# 44936719552125, 7.881206795290213, 7.887919918625213, 7.894633041960214, 7.901
# 346165295214, 7.908059288630215, 7.914772411965215, 7.921485535300215, 7.92819
# 8658635216, 7.934911781970216, 7.941624905305217, 7.948338028640217, 7.9550511
# 51975217, 7.961764275310218, 7.968477398645218, 7.975190521980219, 7.981903645
# 315219, 7.988616768650219, 7.99532989198522, 8.00204301532022, 8.0087561386552
# 2, 8.015469261990221, 8.022182385325221, 8.028895508660222, 8.035608631995222,
#  8.042321755330223, 8.049034878665223, 8.055748002000223, 8.062461125335224, 8
# .069174248670224, 8.075887372005225, 8.082600495340225, 8.089313618675225, 8.0
# 96026742010226, 8.102739865345226, 8.109452988680227, 8.116166112015227, 8.122
# 879235350227, 8.129592358685228, 8.136305482020228, 8.143018605355229, 8.14973
# 1728690229, 8.15644485202523, 8.16315797536023, 8.16987109869523, 8.1765842220
# 3023, 8.183297345365231, 8.190010468700232, 8.196723592035232, 8.2034367153702
# 32, 8.210149838705233, 8.216862962040233, 8.223576085375234, 8.230289208710234
# , 8.237002332045234, 8.243715455380235, 8.250428578715235, 8.257141702050236,
# 8.263854825385236, 8.270567948720236, 8.277281072055237, 8.283994195390237, 8.
# 290707318725238, 8.297420442060238, 8.304133565395238, 8.310846688730239, 8.31
# 755981206524, 8.32427293540024, 8.33098605873524, 8.33769918207024, 8.34441230
# 540524, 8.351125428740241, 8.357838552075242, 8.364551675410242, 8.37126479874
# 5242, 8.377977922080243, 8.384691045415243, 8.391404168750244, 8.3981172920852
# 44, 8.404830415420244, 8.411543538755245, 8.418256662090245, 8.424969785425246
# , 8.431682908760246, 8.438396032095246, 8.445109155430247, 8.451822278765247,
# 8.458535402100248, 8.465248525435248, 8.471961648770248, 8.478674772105249, 8.
# 48538789544025, 8.49210101877525, 8.49881414211025, 8.50552726544525, 8.512240
# 388780251, 8.518953512115251, 8.525666635450252, 8.532379758785252, 8.53909288
# 2120253, 8.545806005455253, 8.552519128790253, 8.559232252125254, 8.5659453754
# 60254, 8.572658498795255, 8.579371622130255, 8.586084745465255, 8.592797868800
# 256, 8.599510992135256, 8.606224115470257, 8.612937238805257, 8.61965036214025
# 7, 8.626363485475258, 8.633076608810258, 8.639789732145259, 8.646502855480259,
#  8.65321597881526, 8.65992910215026, 8.66664222548526, 8.67335534882026, 8.680
# 068472155261, 8.686781595490261, 8.693494718825262, 8.700207842160262, 8.70692
# 0965495263, 8.713634088830263, 8.720347212165263, 8.727060335500264, 8.7337734
# 58835264, 8.740486582170265, 8.747199705505265, 8.753912828840265, 8.760625952
# 175266, 8.767339075510266, 8.774052198845267, 8.780765322180267, 8.78747844551
# 5267, 8.794191568850268, 8.800904692185268, 8.807617815520269, 8.8143309388552
# 69, 8.82104406219027, 8.82775718552527, 8.83447030886027, 8.84118343219527, 8.
# 847896555530271, 8.854609678865272, 8.861322802200272, 8.868035925535272, 8.87
# 4749048870273, 8.881462172205273, 8.888175295540274, 8.894888418875274, 8.9016
# 01542210274, 8.908314665545275, 8.915027788880275, 8.921740912215276, 8.928454
# 035550276, 8.935167158885276, 8.941880282220277, 8.948593405555277, 8.95530652
# 8890278, 8.962019652225278, 8.968732775560278, 8.975445898895279, 8.9821590222
# 3028, 8.98887214556528, 8.99558526890028, 9.00229839223528, 9.00901151557028,
# 9.015724638905281, 9.022437762240282, 9.029150885575282, 9.035864008910282, 9.
# 042577132245283, 9.049290255580283, 9.056003378915284, 9.062716502250284, 9.06
# 9429625585284, 9.076142748920285, 9.082855872255285, 9.089568995590286, 9.0962
# 82118925286, 9.102995242260286, 9.109708365595287, 9.116421488930287, 9.123134
# 612265288, 9.129847735600288, 9.136560858935288, 9.143273982270289, 9.14998710
# 560529, 9.15670022894029, 9.16341335227529, 9.17012647561029, 9.17683959894529
# , 9.183552722280291, 9.190265845615292, 9.196978968950292, 9.203692092285293,
# 9.210405215620293, 9.217118338955293, 9.223831462290294, 9.230544585625294, 9.
# 237257708960295, 9.243970832295295, 9.250683955630295, 9.257397078965296, 9.26
# 4110202300296, 9.270823325635297, 9.277536448970297, 9.284249572305297, 9.2909
# 62695640298, 9.297675818975298, 9.304388942310299, 9.311102065645299, 9.317815
# 1889803, 9.3245283123153, 9.3312414356503, 9.3379545589853, 9.344667682320301,
#  9.351380805655301, 9.358093928990302, 9.364807052325302, 9.371520175660303, 9
# .378233298995303, 9.384946422330303, 9.391659545665304, 9.398372669000304, 9.4
# 05085792335305, 9.411798915670305, 9.418512039005305, 9.425225162340306, 9.431
# 938285675306, 9.438651409010307, 9.445364532345307, 9.452077655680307, 9.45879
# 0779015308, 9.465503902350308, 9.472217025685309, 9.478930149020309, 9.4856432
# 7235531, 9.49235639569031, 9.49906951902531, 9.50578264236031, 9.5124957656953
# 11, 9.519208889030311, 9.525922012365312, 9.532635135700312, 9.539348259035313
# , 9.546061382370313, 9.552774505705314, 9.559487629040314, 9.566200752375314,
# 9.572913875710315, 9.579626999045315, 9.586340122380316, 9.593053245715316, 9.
# 599766369050316, 9.606479492385317, 9.613192615720317, 9.619905739055318, 9.62
# 6618862390318, 9.633331985725318, 9.640045109060319, 9.64675823239532, 9.65347
# 135573032, 9.66018447906532, 9.66689760240032, 9.67361072573532, 9.68032384907
# 0321, 9.687036972405322, 9.693750095740322, 9.700463219075322, 9.7071763424103
# 23, 9.713889465745323, 9.720602589080324, 9.727315712415324, 9.734028835750324
# , 9.740741959085325, 9.747455082420325, 9.754168205755326, 9.760881329090326,
# 9.767594452425326, 9.774307575760327, 9.781020699095327, 9.787733822430328, 9.
# 794446945765328, 9.801160069100328, 9.807873192435329, 9.81458631577033, 9.821
# 29943910533, 9.82801256244033, 9.83472568577533, 9.84143880911033, 9.848151932
# 445331, 9.854865055780332, 9.861578179115332, 9.868291302450332, 9.87500442578
# 5333, 9.881717549120333, 9.888430672455334, 9.895143795790334, 9.9018569191253
# 34, 9.908570042460335, 9.915283165795335, 9.921996289130336, 9.928709412465336
# , 9.935422535800337, 9.942135659135337, 9.948848782470337, 9.955561905805338,
# 9.962275029140338, 9.968988152475339, 9.975701275810339, 9.98241439914534, 9.9
# 8912752248034, 9.99584064581534, 10.00255376915034, 10.009266892485341, 10.015
# 980015820341, 10.022693139155342, 10.029406262490342, 10.036119385825343, 10.0
# 42832509160343, 10.049545632495343, 10.056258755830344, 10.062971879165344, 10
# .069685002500345, 10.076398125835345, 10.083111249170345, 10.089824372505346,
# 10.096537495840346, 10.103250619175347, 10.109963742510347, 10.116676865845347
# , 10.123389989180348, 10.130103112515348, 10.136816235850349, 10.1435293591853
# 49, 10.15024248252035, 10.15695560585535, 10.16366872919035, 10.17038185252535
# , 10.177094975860351, 10.183808099195351, 10.190521222530352, 10.1972343458653
# 52, 10.203947469200353, 10.210660592535353, 10.217373715870353, 10.22408683920
# 5354, 10.230799962540354, 10.237513085875355, 10.244226209210355, 10.250939332
# 545355, 10.257652455880356, 10.264365579215356, 10.271078702550357, 10.2777918
# 25885357, 10.284504949220358, 10.291218072555358, 10.297931195890358, 10.30464
# 4319225359, 10.31135744256036, 10.31807056589536, 10.32478368923036, 10.331496
# 81256536, 10.33820993590036, 10.344923059235361, 10.351636182570362, 10.358349
# 305905362, 10.365062429240362, 10.371775552575363, 10.378488675910363, 10.3852
# 01799245364, 10.391914922580364, 10.398628045915364, 10.405341169250365, 10.41
# 2054292585365, 10.418767415920366, 10.425480539255366, 10.432193662590366, 10.
# 438906785925367, 10.445619909260367, 10.452333032595368, 10.459046155930368, 1
# 0.465759279265368, 10.472472402600369, 10.47918552593537, 10.48589864927037, 1
# 0.49261177260537, 10.49932489594037, 10.50603801927537, 10.512751142610371, 10
# .519464265945372, 10.526177389280372, 10.532890512615372, 10.539603635950373,
# 10.546316759285373, 10.553029882620374, 10.559743005955374, 10.566456129290374
# , 10.573169252625375, 10.579882375960375, 10.586595499295376, 10.5933086226303
# 76, 10.600021745965376, 10.606734869300377, 10.613447992635377, 10.62016111597
# 0378, 10.626874239305378, 10.633587362640379, 10.640300485975379, 10.647013609
# 31038, 10.65372673264538, 10.66043985598038, 10.66715297931538, 10.67386610265
# 0381, 10.680579225985381, 10.687292349320382, 10.694005472655382, 10.700718595
# 990383, 10.707431719325383, 10.714144842660383, 10.720857965995384, 10.7275710
# 89330384, 10.734284212665385, 10.740997336000385]

# %%
ikszvearray=array(ikszvelist)          # A plot-beli indexeléshez kétindexes array-vé alakította.

plt.figure(figsize=(15, 10))
plot(masodiktlist[:1000],ikszvearray[:1000,0], "o-")  # Ábrázolta.
axhline(0,color="r")

# %%
#Hibakereses

lennardjonesero(1)

# %%
masodiktlist[-1]

# %%
ikszvearray

# %%
ikszvearray=array(ikszvelist)          # A plot-beli indexeléshez kétindexes array-vé alakította.
plot(masodiktlist[:1000],ikszvearray[:1000,1], "o-")  # Ábrázolta.
axhline(0,color="r")

# %%
sebessegek2 = [element[1] for element in ikszvelist]

# %%
sebessegek2

# %%
helyek2 = [element[0] for element in ikszvelist]

# %%
energiaertekek2 = []

# %%
for i in range(0, len(ikszvelist)):
    
    energia = lennardjonespotencial(helyek[i])+1/2*1*sebessegek[i]**2
    
    energiaertekek2.append(energia)

# %%
energiakulonbseg2= []

for i in energiaertekek2:
    
    energiakulonbseg2.append(i-Energianull)

# %%
plt.plot(masodiktlist[:100], energiakulonbseg2[:100])

# %%
#Az Euler-módszer megvalósítása harmonikus oszcillátorra

# %%
def harmonikusmozgas(t, ikszve):
    
    k=1
    
    xpont = ikszve[1]         #Itt adom meg, hogy x derivaltja a sebesség
    vpont = -k*ikszve[0]              #Itt adom meg a ható erő nagyságát
    
    
    return [xpont, vpont]

# %%
#Hibakereses

lennardjonesero(1)

# %%
x0, t0, tlist[-1]

# %%
ikszvearray

# %%
ikszvearray[0][1]

# %%
import numpy as np
import matplotlib.pyplot as plt

lepeskoz = tlist[-1]/len(tlist)

k = 1
k4 = 1
parameterV0 = 1
parameterx0=1

tvegso = tlist[-1]

def euler_harmonikus_oszcillator(ve0, kezdetihely,  t0, tvegso, lepeskoz):
    
    
    #ve0 a kezdeti sebesség
    #x0 a kezdeti kitérés
    #t0 a kezdőidőpont (0)
    #tvegso - ameddig léptetek
    
    
    t = np.arange(t0, tvegso + lepeskoz, lepeskoz)
    iksz = np.zeros_like(t)
    ve = np.zeros_like(t)
    iksz[0] = kezdetihely
    ve[0] = ve0
    
    for i in range(len(t) - 1):
        
        #szorzo = (12*parameterV0*parameterx0**12)/(iksz[i]**13) + 12*parameterV0*parameterx0**6/(iksz[i]**7)
        ve[i + 1] = ve[i] - k*iksz[i] * lepeskoz
        iksz[i + 1] = iksz[i] + ve[i] * lepeskoz
        


    return t, iksz, ve

# %%
#Hibakereses

lennardjonesero(1)

# %%
t0=0
x0=x0/3
ikszve0=[x0,0] 

kezdetihely = 1

# %%
t, iksz, ve = euler_harmonikus_oszcillator(0, kezdetihely,  t0, tvegso, lepeskoz)

# %%
plt.figure(figsize=(15, 10))

plt.plot(t, iksz)
plt.grid()

# %%
energiaertekek3 = []
for i in range(0, len(t)):
    
    energia = harmonikuspotencial(iksz[i])+1/2*1*ve[i]**2
    
    energiaertekek3.append(energia)

# %%
energiakulonbseg3= []

Energianull = harmonikuspotencial(iksz[0])+1/2*1*ve[0]**2

for i in energiaertekek3:
    
    energiakulonbseg3.append(i-Energianull)

# %%
plt.figure(figsize=(15, 10))
plt.plot(t, energiakulonbseg3)

plt.grid()

# %%
#Az Euler-módszer megvalósítása Lennard-Jones potenciál esetén:

# %%
len(masodiktlist)

# %%
masodiktlist[-1]

# %%
lennardjonesero(1)

# %%
def euler_lennard_jones(ve0, kezdetihely,  t0, tvegso, lepeskoz):
    
    #ve0 a kezdeti sebesség
    #x0 a kezdeti kitérés
    #t0 a kezdőidőpont (0)
    #tvegso - ameddig léptetek
    
    
    t = np.arange(t0, tvegso + lepeskoz, lepeskoz)
    iksz = np.zeros_like(t)
    ve = np.zeros_like(t)
    iksz[0] = kezdetihely
    ve[0] = ve0
    
    for i in range(len(t) - 1):
        
        #szorzo = (12*parameterV0*parameterx0**12)/(iksz[i]**13) + 12*parameterV0*parameterx0**6/(iksz[i]**7)
        ve[i + 1] = ve[i] - lennardjonesero(iksz[i]) * lepeskoz
        iksz[i + 1] = iksz[i] + ve[i] * lepeskoz
        
        #lennardjones  = V0*((x0**12)/(x**12)-2*((x0**6/x**6)))
        


    return t, iksz, ve

# %%
#x0=4/3
#v0= 2

# %%
lennardjonespotencial(1)

# %%
lennardjonesero(1)

# %%
tlennardjones, ikszlennardjones, velennardjones = euler_lennard_jones(0, x0,  t0, tvegso, lepeskoz)

# %%
plt.plot(tlennardjones, ikszlennardjones)

# %%
plt.plot(tlennardjones, velennardjones)

# %% [markdown]
# ## Teljes 4.a) feladatrész
#
# A következő feladatrészben Fourier spektrumot kell számolnunk, amit közvetlenül csak időben egyenletes lépésközű adatokon kaphatunk meg. Az adaptív lépésközű integrálás bár hasznos, azonban a koordináta értékek nem egyenletes lépésközzel adódtak ki. Ezért interpoláljuk a 3. feladatrészből kapott megoldásokat időben egyenletes lépésközzel, lineárisan és köbös spline-ok segítségével!
#
# Az interpolációhoz a scipy.interpolate csomag interp1d() függvényének használata javasolt.
# Ha van egy t listában, vagy arrayben tárolt időpont sorozatunk és egy y listában/arrayben a hozzájuk tartozó függvényértékek, akkor ezekhez az alábbi módon tudunk interpolációt végezni:
#
# ill=interp1d(t,y)
#
# Az eredmény még nem adatsor lesz, hanem egy függvény, amit ill(t1) módon meghívva kapjuk az illesztett függvény értékeit. Alapból az illesztés lineáris, tehát a beadott adatsorok értékeiből alkotott szakaszonként egyenes függvény t1-nél felvett értékét kapjuk meg. A 'cubic' opciót az interp1d-ben megadva az illesztés köbös lesz.
# Az eredményül kapott ill függvénynek, mint legtöbb python függvénynek egyszerre több értéket is adhatunk egy listában, vagy arrayben.
#
# Hasonlítsuk össze a lineáris és köbös illesztés eredményét!

# %%
# a megoldás helye

# %%
from scipy import interpolate

# %%
f = interpolate.interp1d(elsotlist, helyek)

# %%
elsotlist[-1]

# %%
elsolistnew = np.arange(0, elsotlist[-1], 0.1)
helyeknew = f(elsolistnew)   # use interpolation function returned by `interp1d`
plt.figure(figsize=(15, 10))
plt.plot(elsotlist, helyek, 'o', elsolistnew, helyeknew, '-')
plt.show()

# %%
fcubic = interpolate.interp1d(elsotlist, helyek, kind='cubic')

# %%
elsolistcubicnew = np.arange(0, elsotlist[-1], 0.1)
helyekcubicnew = f(elsolistcubicnew)   # use interpolation function returned by `interp1d`
plt.figure(figsize=(15, 10))
plt.plot(elsotlist, helyek, 'o', elsolistcubicnew, helyekcubicnew, '-')
plt.show()

# %%
f3 = interpolate.interp1d(masodiktlist, helyek2)

# %%
masodiklistnew = np.arange(0, 10.7, 0.1)
helyek2new = f3(masodiklistnew)   # use interpolation function returned by `interp1d`
plt.plot(masodiktlist, helyek2, 'o', masodiklistnew, helyek2new, '-')
plt.figure(figsize=(15, 10))
plt.show()

# %% [markdown]
# ## Teljes 4.b) feladatrész
#
# Számítsuk ki, és ábrázoljuk a felprogramozott oszcillátorok Fourier-spektrumát! Mivel valós a jelünk, ehhez javasolt az rfft() és rfftfreq() függvények használata. Mit figyelhetünk meg? Próbáljuk elérni, hogy az alapharmónikusnak megfelelő csúcs félértékszélessége legfeljebb a hozzá tartozó frekvenciaérték 2%-a körül legyen. Nyilván ehhez el kell érni, hogy a frekvenciaskála lépésköze legfeljebb e frekvencia 1%-a körül legyen. Ehhez elegendő hosszan kell a rendszer megoldását futtatni. Ugyanakkor vigyázzunk, mert ha túl hosszan futtatjuk és halmozódnak a hibák (észrevehetően változik az amplitúdó), az is a csúcsok kiszélesedéséhez vezethet!

# %%
# a megoldás helye

# %%
elsotlist[-1]

# %%
yf = np.fft.rfft(helyeknew)
xf = np.fft.rfftfreq(len(helyeknew), 500)

# %%
yfcubic = np.fft.rfft(helyekcubicnew)
xfcubic = np.fft.rfftfreq(len(helyekcubicnew), 500)

# %%
plt.figure(figsize=(15, 10))
plt.plot(xf[:150], yf[:150])
plt.plot(xfcubic[:150], yfcubic[:150], '--',  color="blue", linewidth=3)
plt.grid()

# %% [markdown]
# ## <font color='green5'>5. Szorgalmi feladatrész</font>
#
# Programozzunk be kaotikus oszcillátort!$^1$ Egy szinuszosan gerjesztett oszcillátor esetében a kaotikus viselkedés feltétele, hogy a visszatérítő erő ne lineáris függvénye legyen a kitérésnek. Ábrázoljuk a kitérés és a sebesség időfüggését, valamint a teljesítményspektrumot! Futassuk az integrálást legalább 1 millió lépésig, és ábrázoljuk a rendszer Poincaré-metszetét, azaz a sebességet a kitérés függvényében az $\omega t = n \cdot 2 \pi, n = 1, 2, 3, ... $ feltétel mellett!
#
# $^1$ http://sprott.physics.wisc.edu/pubs/paper265.pdf

# %%
# a megoldás helye
